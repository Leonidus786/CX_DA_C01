# %% [markdown]
# ### Modules :- In python, modules and packages help organise and reuse code.

# %%
import math

# %%
print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'sumprod', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %%
from math import sqrt,pi

# %%
print(sqrt(25))
print(pi)   # how to control digits after decimal
# Out:
# 5.0
# 3.141592653589793

# %%
print(f"{pi:.2f}")
# Out:
# 3.14

# %%
import numpy as np

# %%
np.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
from math import *

# %%
from packages.My_module import addition

# %%
addition(100,200)
# Out:
# 300

# %%
from packages.My_module import multiply

# %%
multiply(4,3)
# Out:
# 12

# %%
from packages.maths import factorial, addition, multiply

# %%
factorial(6)   # 6*5*4*3*2*1
# Out:
# 720

# %%
addition(4,5)
# Out:
# 9

# %%
multiply(3,3)
# Out:
# 9

# %%
import random

# %%
print(random.randint(1,1000))
# Out:
# 449

# %%
import os

# %%
print(os.getcwd())
# Out:
# d:\CX_DA_C01\Python\Day_7
