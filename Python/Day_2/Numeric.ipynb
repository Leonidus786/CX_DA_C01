# %%
int(input("Please enter a number between 1-10.: "))
# Out:
# 12

# %%
Number = int(input("Please enter your mobile number between 1.: "))

Number
# Out:
# 3445

# %%
n = float(5)

n
# Out:
# 5.0

# %%
Number
# Out:
# 3445

# %%
Number + n
# Out:
# 3450.0

# %%
Number * n
# Out:
# 17225.0

# %%
23 * 67 * 345
# Out:
# 531645

# %%
Number -  n
# Out:
# 3440.0

# %%
Number/n
# Out:
# 689.0

# %%
Number
# Out:
# 3445

# %%
Complex_1 = complex(Number)

Complex_1
# Out:
# (3445+0j)

# %%
c = int(Complex_1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 c = int(Complex_1)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
d = complex(n)

# %%
d
# Out:
# (5+0j)

# %%
e = float(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 e = float(d)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
Complex_1+ d
# Out:
# (3450+0j)

# %%
Complex_1 * d
# Out:
# (17225+0j)

# %% [markdown]
# ## integers can be converted in  any data.
#
# ## foats can be converteed
