# %%
Name = "Abhishek"

Age = 30

type(Age)
# Out:
# int

# %%
# Modify strings

Name_1=Name.upper()

# %%
Name_1
# Out:
# 'ABHISHEK'

# %%
Name.upper()
# Out:
# 'ABHISHEK'

# %%
Name
# Out:
# 'Abhishek'

# %%
Name.lower()
# Out:
# 'abhishek'

# %%
n = "Hello, World!"

# %%
n.replace("H", "J")
# Out:
# 'Jello, World!'

# %%
n.split(",")
# Out:
# ['Hello', ' World!']

# %%
# Concatenation

First_name = "Abhishek"

Last_name = "Upadhayay"

# %%
Full_name = First_name +" "+ Last_name

Full_name
# Out:
# 'Abhishek Upadhayay'

# %%
Name
# Out:
# 'Abhishek'

# %%
Age
# Out:
# 30

# %%
msg = "My name is "+ Name+ " and my age is "+ str(Age)
print(msg)


# msg_1 = 'Good Noon My name is '+Name + " and my age is "+ Age
# Out:
# My name is Abhishek and my age is 30

# %%
Maths = 85
English = 75
Social_Science = 78
Science = 79
Sanskrit = 80
Hindi = 79

# %%
Report = "Hi guys my marks in maths "+str(Maths)+" and in English is"+ str(English)
Report
# Out:
# 'Hi guys my marks in maths 85 and in English is75'

# %%
"Abhishek" + str(5)
# Out:
# 'Abhishek5'

# %% [markdown]
# ### f- strings == f"{Placeholder}or{Modifiers} what can you keep is {Var_name} "
#
# -- f-strings is used for formatting strings.

# %%
Report = f"Hi guys my marks in maths is {Maths}, and in english it is {English}, also I got {Science} in Science."

# %%
Report
# Out:
# 'Hi guys my marks in maths is 85, and in english it is 75, also I got 79 in Science.'

# %%
type(Maths)
# Out:
# int

# %%
mag = f"My name is {Name} and my age is {Age}."

# %%
mag
# Out:
# 'My name is Abhishek and my age is 30.'

# %%
old_price = 59
txt = f"The new price is {old_price + 5} dollars."
print(txt)
# Out:
# The new price is 64 dollars.

# %%
# 59.00
price = 59
txt = f"The price is {price:.2f} dollars"
print(txt)
# Out:
# The price is 59.00 dollars

# %%
22/7
# Out:
# 3.142857142857143

# %%
value = f"the value of pi is {22/7:.3f}"
value
# Out:
# 'the value of pi is 3.143'

# %%
msg = "I am an "AI" Engineer"
msg
# Out:
#   Cell In[34], line 1
#     msg = "I am an "AI" Engineer"
#                     ^
# SyntaxError: invalid syntax

# %%
# Way - 1
msg = "I am a \"AI\" enginner"
print(msg)
# Out:
# I am a "AI" enginner

# %%
# Way -2

msg = 'I am a "AI" enginner'
msg
# Out:
# 'I am a "AI" enginner'

# %%
msg = "I am a 'AI' enginner"
msg
# Out:
# "I am a 'AI' enginner"

# %%
# \n == new line character -- line continuation

# %%
txt = "Hello\nWorld!\nI am here to learn python"
print(txt)
# Out:
# Hello
# World!
# I am here to learn python

# %%
msg = "I am Abhishek\nI am an AI developer"

print(msg)
# Out:
# I am Abhishek
# I am an AI developer

# %%
msg = "I am Abhishek\nI am an AI Developer."
print(msg)
# Out:
# I am Abhishek
# I am an AI Developer.

# %%
a = "abhishek"

print(a)
# Out:
# abhishek

# %%
print(a.capitalize())
# Out:
# Abhishek

# %%
b = "Hello, World!"
print(b[:5])
# Out:
# Hello

# %%
a
# Out:
# 'abhishek'

# %%
d_1 = a.upper()
d_1
# Out:
# 'ABHISHEK'

# %%
d_1.lower()
# Out:
# 'abhishek'

# %%
saying = "      Yashi             Chauhan                  "


saying
# Out:
# '      Yashi             Chauhan                  '

# %%
saying.strip()
# Out:
# 'Yashi             Chauhan'

# %%
a = "Hello, World!"
print(a.replace("H", "J"))
# Out:
# Jello, World!
