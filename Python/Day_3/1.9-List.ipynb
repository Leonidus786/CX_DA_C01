# %% [markdown]
# [] -- Square braces
# {} -- curly braces
# () -- parentheses
#
#
# ## List
#
# - Lists are used to store multiple items in a single variable.
#
# - Lists are one of 4 built-in data types in Python used to store collections of data, the other 3 are Tuple, Set, and Dictionary, all with different qualities and usage.
#
# - Lists are created using square brackets and list().

# %%
class_room = ["naina", 1, 2, 3.5, 3 + 2j, True, False, [1,2,3]]

# %%
print(type(class_room))
# Out:
# <class 'list'>

# %%
class_room
# Out:
# ['naina', 1, 2, 3.5, (3+2j), True, False, [1, 2, 3]]

# %%
flowers = list(("Roses", "Marigold", "Lotus", "Lily"))
flowers_1 = list(["Roses", "Marigold", "Lotus", "Lily"])
flowers_2 = list({"Roses", "Marigold", "Lotus", "Lily"})


print(flowers)
print(flowers_1)
print(flowers_2)
# Out:
# ['Roses', 'Marigold', 'Lotus', 'Lily']
# ['Roses', 'Marigold', 'Lotus', 'Lily']
# ['Lily', 'Roses', 'Marigold', 'Lotus']

# %%
len(class_room)
# Out:
# 8

# %%
class_room
# Out:
# ['naina', 1, 2, 3.5, (3+2j), True, False, [1, 2, 3]]

# %%
class_room[0]
# Out:
# 'naina'

# %%
len(class_room)
# Out:
# 8

# %%
class_room[-7]
# Out:
# 1

# %%
class_room[0:3]
# Out:
# ['naina', 1, 2]

# %%
thislist = ["apple", "banana", "cherry"]


# print(thislist[1])




thislist[1] = "blackcurrant"
print(thislist)
# Out:
# banana
# ['apple', 'blackcurrant', 'cherry']

# %%
my_list = ["apple", "banana", "cherry"]
print(my_list)
my_list[1:3] = ["blackcurrant", "watermelon"]
# Out:
# ['apple', 'banana', 'cherry']

# %%
print(my_list)
# Out:
# ['apple', 'blackcurrant', 'watermelon']

# %% [markdown]
# ## Insert Items
# To insert a new list item, without replacing any of the existing values, we can use the insert() method.
#
# The insert() method inserts an item at the specified index

# %%
thislist = ["apple", "banana", "cherry"]
thislist.insert(2, "watermelon")
print(thislist)
# Out:
# ['apple', 'banana', 'watermelon', 'cherry']

# %% [markdown]
# ## Append Items
# To add an item to the end of the list, use the append() method.

# %%
thislist.append("orange")
print(thislist)
# Out:
# ['apple', 'banana', 'watermelon', 'cherry', 'orange']

# %% [markdown]
# ## Extend List
# To append elements from another list to the current list, use the extend() method.

# %%
thislist = ["apple", "banana", "cherry"]
tropical = ["mango", "pineapple", "papaya"]
thislist.extend(tropical)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'pineapple', 'papaya']

# %%
thislist = ["apple", "banana", "cherry"]
thistuple = ("kiwi", "orange")
thislist.extend(thistuple)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'kiwi', 'orange']

# %% [markdown]
# ## Remove Specified Item
# The remove() method removes the specified item. If you know the item not the index.

# %%
thislist.remove("apple")

# %%
thislist
# Out:
# ['banana', 'cherry', 'kiwi', 'orange']

# %% [markdown]
# ## Remove Specified Index
# The pop() method removes the specified index.

# %%
thislist = ["apple", "banana", "cherry"]
thislist.pop(1)
print(thislist)
# Out:
# ['apple', 'cherry']

# %%
# If you do not specify the index, the pop() method removes the last item.
thislist = ["apple", "banana", "cherry"]
thislist.pop()
print(thislist)
# Out:
# ['apple', 'banana']

# %% [markdown]
# ## The del keyword also removes the specified index.
# ## The del keyword can also delete the list completely.

# %%
thislist = ["apple", "banana", "cherry"]
del thislist[0]
print(thislist)
# Out:
# ['banana', 'cherry']

# %%
del thislist

# %%
thislist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 thislist
#
# NameError: name 'thislist' is not defined

# %% [markdown]
# ## Clear the List
# The clear() method empties the list.
#
# The list still remains, but it has no content.

# %%
thislist = ["apple", "banana", "cherry"]
thislist.clear()
print(thislist)
# Out:
# []

# %%
lst = []

# %%
thislist
# Out:
# ['apple', 'banana', 'watermelon', 'cherry']

# %%
for z in thislist:
    print(z)
# Out:
# apple
# banana
# watermelon
# cherry

# %%
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"]
thislist.sort()
print(thislist)
# Out:
# ['banana', 'kiwi', 'mango', 'orange', 'pineapple']

# %%
thislist = [100, 50, 10, 96, 78.234, 65, 82, 23]
thislist.sort()
print(thislist)
# Out:
# [10, 23, 50, 65, 78.234, 82, 96, 100]

# %% [markdown]
# ### Sort Descending
# To sort descending, use the keyword argument reverse = True

# %%
thislist = [100, 50, 10, 96, 78.234, 65, 82, 23]

# %%
thislist.sort(reverse = True)

# %%
thislist
# Out:
# [100, 96, 82, 78.234, 65, 50, 23, 10]

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist.copy()
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
mylist = list(thislist)
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist[:]
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist.append(7)

# %%
thislist
# Out:
# ['apple', 'banana', 'cherry', 7]

# %%
mylist
# Out:
# ['apple', 'banana', 'cherry']

# %%
# List comprhension


my_list_1 = ['call', "Bike", "Aeroplane"]

list_1 = []


for a in my_list_1:
    list_1.append(a)

# %%
list_1
# Out:
# ['call', 'Bike', 'Aeroplane']

# %%
list_2 =[a for a in my_list_1]

# %%
list_2
# Out:
# ['call', 'Bike', 'Aeroplane']
