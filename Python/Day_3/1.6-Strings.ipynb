# %% [markdown]
# ### Strings ---> Set of characters. or you can say array of characters.

# %%
Address = "Gurugram" 

Name = 'Abhishek'

name = "Amit"

name_1 = '''Delhi'''

Name_1 = """Mumbai"""

# %%
print(Address)
print(name)
print(Name)
print(name_1)
print(Name_1)
# Out:
# Gurugram
# Amit
# Abhishek
# Delhi
# Mumbai

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
# If you have to write multilines then use '''''', """""".
print("""The Zen of Python, by Tim Peters

Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.""")
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.

# %%
Name
# Out:
# 'Abhishek'

# %%
#  if you want to get the number of characters 

len(Name)
# Out:
# 8

# %%
len(Name_1)
# Out:
# 6

# %%
print(Name_1)
# Out:
# Mumbai

# %%
name
# Out:
# 'Amit'

# %%
# this is +ve indexing--- how to access characters of a string

print(name[0])

name[0]
# Out:
# A
# 'A'

# %%
print(name[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(name[4])
#
# IndexError: string index out of range

# %%
# Negative indexing -- counting starts from -1
print(name[-5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Negative indexing -- counting starts from -1
# ----> 2 print(name[-5])
#
# IndexError: string index out of range

# %%
Name
# Out:
# 'Abhishek'

# %%
name[-4]
# Out:
# 'A'

# %%
len(Name)
# Out:
# 8

# %%
# Slicing === [Start:End]
print(Name[0:5])
# Out:
# Abhis

# %%
name[0:4]
# Out:
# 'Amit'

# %%
say = "The quick brown fox jumps over the lazy dog"

len(say)
# Out:
# 43

# %%
say[0:20]
# Out:
# 'The quick brown fox '

# %%
say[-43:-24]
# Out:
# 'The quick brown fox'

# %%
# say[:20]
say[:-24]
# Out:
# 'The quick brown fox'

# %%
class_1 = "This is python for Data Analysis"

# %%
len(class_1)
# Out:
# 32

# %%
class_1[:]
# Out:
# 'This is python for Data Analysis'

# %%
class_1[3:31]
# Out:
# 's is python for Data Analysi'

# %%
class_1
# Out:
# 'This is python for Data Analysis'

# %%
print("c++" in class_1)
# Out:
# False

# %%
"Python" in class_1
# Out:
# False

# %%
"python" in class_1
# Out:
# True

# %%
"c"  not in class_1
# Out:
# True
