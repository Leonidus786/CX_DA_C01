# %%
a = int(input("Enter a number"))
type(a)
# Out:
# int

# %% [markdown]
# ## https://www.geeksforgeeks.org/competitive-programming/an-introduction-to-flowcharts/

# %% [markdown]
# # if
#
# # elif == else if
#
# # else

# %%
Choose_Something = input("What do you want to choose after 10th:(Science, Arts, Commerce): ")
print(f"you have selected {Choose_Something}")

if Choose_Something == "Science":
    print("ghr chod k niklo bina soche")
elif Choose_Something == "Arts":
    print("1 month mauj kro")
else:
    print("moms wale prathe apko roj milenge")
# Out:
# you have selected Commerce
# moms wale prathe apko roj milenge

# %%
a = 2

if a == 3:
    print("This is good")

# %%
a = int(input("Please enter a number.: "))

if a >= 10:
    print("a is greater")
else:
    print("do nothing")
# Out:
# do nothing

# %%
a = int(input("Please enter a number.: "))
a
# Out:
# 0

# %%
if a ==2:
    print("do this")
elif a >= 2:
    print("ab m v chalunga")
elif a > 2:
    print("Mai v chl skta hu")
else:
    print("Bhaukaal h iska")
# Out:
# Bhaukaal h iska

# %%
import keyword

# %%
print(keyword.kwlist)
