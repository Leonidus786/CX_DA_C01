# %% [markdown]
# 1. Introduction to Operators
# 2. Arithmetic Operators
#    - Addition
#    - Subtraction
#    - Multiplication
#    - Division
#    - Floor Division
#    - Modulus
#    - Exponentiation
# 3. Comparison Operators
#    - Equal to
#    - Not equal to
#    - Greater than
#    - Less than
#    - Greater than or equal to
#    - Less than or equal to
# 4. Logical Operators
#    - AND
#    - OR
#    - NOT
# 5. Practical Examples and Common Errors
#
# Hint-- https://www.geeksforgeeks.org/complete-reference-for-bitwise-operators-in-programming-coding/

# %%
x = 35

y = 7

z = 7

# %%
print(x + y)
print(x - y)
print(y - x)
print(x * y)
print(x / y) # whenever you divide things in python you always end up with getting a floating point number.
print(x // y) # floor divison -- quotient without decimals
print(x % y) # Modulo -- % -- Remainder

# 2 raised to the power of 5 == 2 *2 *2 *2*2 = 32
print(2 ** 5)
# Out:
# 42
# 28
# -28
# 245
# 5.0
# 5
# 0
# 32

# %%
22//7

22 % 3
# Out:
# 1

# %% [markdown]
# # Try the same with strings as well

# %% [markdown]
# ## comparison operators
# 1. Equal ==
# 2. Not equal !=
# 3. Greater than	>
# 4. Less than <
# 5. Greater than or equal to	>=
# 6. Less than or equal to <=

# %%
x == y
# Out:
# False

# %%
y == z
# Out:
# True

# %%
x > y
# Out:
# True

# %%
x >= y
# Out:
# True

# %%
x < y
# Out:
# False

# %%
x <= y
# Out:
# False

# %%
a = True

b = False

# %%
a and b
# Out:
# False

# %%
a or b
# Out:
# True

# %%
not a
# Out:
# False

# %%
15 & 7
# Out:
# 7

# %%
15 | 7
# Out:
# 15

# %%
15 ^ 7
# Out:
# 8

# %%
~15
# Out:
# -16

# %%
# Negation

~ 7
# Out:
# -8

# %%
7 << 3
# Out:
# 56

# %%
7 >> 3
# Out:
# 0

# %% [markdown]
# ### Identity Operators
# Identity operators are used to compare the objects, not if they are equal, but if they are actually the same object, with the same memory location.
#
# 1. is
# 2. isnot

# %%
x = ["apple", "banana"]
y = ["apple", "banana"]
z = x

# print(id(x))
# print(id(y))
# print(id(z))

# print(x)
# print(y)
# print(z)


print(x is z)

# returns True because z is the same object as x

print(x is y)

# returns False because x is not the same object as y, even if they have the same content

print(x == y)

# to demonstrate the difference betweeen "is" and "==": this comparison returns True because x is equal to y

x is not y
# Out:
# True
# False
# True
# True

# %% [markdown]
# ### Membership Operators
# Membership operators are used to test if a sequence is presented in an object.
#
# 1. in
# 2. not in

# %%
a = "AbhiShek"

# %%
"S" in a
# Out:
# True

# %%
"U" not in a
# Out:
# True
